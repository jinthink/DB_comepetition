# %%
from bs4 import BeautifulSoup
import pandas as pd
import csv
import os
import re
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from pykrx import stock
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, silhouette_score
import FinanceDataReader as fdr
import yfinance as yf
import seaborn as sns
import warnings
warnings.filterwarnings(action = "ignore")

pd.set_option('display.max_rows', None)

# %%
stock_list = []
BaseUrl = 'http://finance.naver.com/sise/entryJongmok.nhn?&page='

for i in range(1, 21):
    url = BaseUrl + str(i)
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'lxml')
    items = soup.find_all('td', {'class': 'ctg'})

    for item in items:
        # print(item)
        txt = item.a.get('href') 
        k = re.search('[\d]+', txt) ##정규표현식 사용. [\d] 숫자표현, + : 반복
        
        if k:
            code = k.group()
            name = item.text
            data = code, name
            stock_list.append(data)
            

# 코스피 상위 200 종목 이름 가져오기
stock_name = []            
for i in range(len(stock_list)):
    stock_name.append(stock_list[i][1])
    
stock_code = []
for i in range(len(stock_list)):
    stock_code.append(stock_list[i][0])

# %%
a = pd.DataFrame(stock_code)
b = pd.DataFrame(stock_name)
df_krx = pd.concat([a,b], axis=1)
df_krx.columns = ["Symbol","Name"]
df_krx.head()
# Out:
#    Symbol      Name
# 0  005930      삼성전자
# 1  373220  LG에너지솔루션
# 2  000660    SK하이닉스
# 3  207940  삼성바이오로직스
# 4  006400     삼성SDI

# %%
import OpenDartReader
api_key = '32203f64a95fa0bc4f72dc1ff7839ec1b4bbe9bd'
dart = OpenDartReader(api_key)

# %%
df_list = []
for i in range(0,200):
    try:
        fin = dart.finstate(df_krx["Name"][i], 2016)
        val = fin[fin["account_nm"] == "매출액"]["thstrm_amount"].iloc[-1]
        df = pd.DataFrame({df_krx["Name"][i] : [val]}, index=[2016])
        df_list.append(df)
    except:
        pass
df = pd.concat(df_list, axis=1)
print(df)
# Out:
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# ...

# %%
df_list = []
for i in range(0,200):
    try:
        fin = dart.finstate(df_krx["Name"][i], 2017)
        val = fin[fin["account_nm"] == "매출액"]["thstrm_amount"].iloc[-1]
        df = pd.DataFrame({df_krx["Name"][i] : [val]}, index=[2017])
        df_list.append(df)
    except:
        pass
df1 = pd.concat(df_list, axis=1)
print(df1)
# Out:
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# ...

# %%
df_list = []
for i in range(0,200):
    try:
        fin = dart.finstate(df_krx["Name"][i], 2018)
        val = fin[fin["account_nm"] == "매출액"]["thstrm_amount"].iloc[-1]
        df = pd.DataFrame({df_krx["Name"][i] : [val]}, index=[2018])
        df_list.append(df)
    except:
        pass
df2 = pd.concat(df_list, axis=1)
print(df2)
# Out:
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# ...

# %%
df_list = []
for i in range(0,200):
    try:
        fin = dart.finstate(df_krx["Name"][i], 2019)
        val = fin[fin["account_nm"] == "매출액"]["thstrm_amount"].iloc[-1]
        df = pd.DataFrame({df_krx["Name"][i] : [val]}, index=[2019])
        df_list.append(df)
    except:
        pass
df3 = pd.concat(df_list, axis=1)
print(df3)
# Out:
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# ...

# %%
df_list = []
for i in range(0,200):
    try:
        fin = dart.finstate(df_krx["Name"][i], 2020)
        val = fin[fin["account_nm"] == "매출액"]["thstrm_amount"].iloc[-1]
        df = pd.DataFrame({df_krx["Name"][i] : [val]}, index=[2020])
        df_list.append(df)
    except:
        pass
df4 = pd.concat(df_list, axis=1)
print(df4)
# Out:
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# ...

# %%
df_list = []
for i in range(0,200):
    try:
        fin = dart.finstate(df_krx["Name"][i], 2021)
        val = fin[fin["account_nm"] == "매출액"]["thstrm_amount"].iloc[-1]
        df = pd.DataFrame({df_krx["Name"][i] : [val]}, index=[2021])
        df_list.append(df)
    except:
        pass
df5 = pd.concat(df_list, axis=1)
print(df5)
# Out:
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# ...

# %%
df2222 = pd.concat([df, df1, df2, df3, df4, df5], axis=0)
df2222.dropna(axis=1, inplace=True)
df2222.head()
# Out:
#                      삼성전자              SK하이닉스              삼성SDI  \
# 2016  133,947,204,000,000  16,733,111,000,000  4,422,860,766,602
# 2017  161,915,007,000,000  29,718,939,000,000  5,421,388,951,623
# 2018  170,381,870,000,000  40,324,651,000,000  8,186,909,424,218
# 2019  154,772,859,000,000  25,320,755,000,000  8,250,811,204,936
# 2020  166,311,191,000,000  30,524,987,000,000  9,101,397,946,638
#
#                     LG화학              NAVER            POSCO홀딩스  \
# 2016  17,264,845,000,000  2,496,498,317,219  24,324,933,259,995
# 2017  20,880,236,000,000  2,930,661,324,862  28,553,814,576,380
# 2018  23,315,318,000,000  3,459,014,042,545  30,659,425,433,515
# 2019  22,312,561,000,000  3,900,013,295,633  30,373,510,738,515
# 2020  20,830,009,000,000  4,126,629,312,584  26,509,920,446,184
#
#                    현대모비스             포스코케미칼                LG전자  \
# 2016  19,860,589,000,000  1,076,455,299,180  28,743,246,000,000
# ...
